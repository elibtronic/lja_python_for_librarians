# %% [markdown]
# # Sci Hub Usage Data Prep for Week 3 Homework
#
# The [original data set](https://datadryad.org/stash/dataset/doi:10.5061/dryad.q447c) to prepare for analysis for Week 3 actvities. This was from a paper published in [Science](https://doi.org/10.1126/science.352.6285.508)

# %% [markdown]
# ## Step 1
#
# Downloading complete dataset & unpack
# - download Zip file from [https://datadryad.org/stash/dataset/doi:10.5061/dryad.q447c](https://datadryad.org/stash/dataset/doi:10.5061/dryad.q447c)
# - unzip
# - navigate to scihub_data directory

# %% [markdown]
# ## Step 2
#
# Search for usage lines that mention Edmonton and Montreal in location, dump into new file
#
# `grep --no-filename -E 'Edmonton|Montreal' *.tab > week_3_scihub.tab`
#
# Move that file back into the main directory

# %%
import pandas
sci_data = pandas.read_csv("week_3_scihub.tab",sep="\t",header=None)
sci_data.columns = ["timestamp","doi_whole","user_id","country","city","coords"]
sci_data
# Out:
#                  timestamp                         doi_whole        user_id  \
# 0      2015-12-01 00:01:32           10.1109/PES.2007.385969  56ed2c29a40f2
# 1      2015-12-01 00:02:23          10.1109/PSC.2014.6808094  56ed2c29a40f2
# 2      2015-12-01 00:03:00          10.1109/PSC.2014.6808094  56ed2c29a40f2
# 3      2015-12-01 00:03:01      10.1007/978-3-642-30574-0_46  56ed2c29a40f2
# 4      2015-12-01 00:04:48           10.1109/PES.2007.385969  56ed2c29a40f2
# ...                    ...                               ...            ...
# 70400  2015-09-30 23:04:48              10.3732/ajb.94.5.887  56ed2b96449d3
# 70401  2015-09-30 23:15:36               10.1021/ja01145a045  56ed2b6a884ae
# 70402  2015-09-30 23:21:29               10.1021/ja02268a023  56ed2b6a884ae
# 70403  2015-09-30 23:58:20              10.5735/085.047.0605  56ed2b96449d3
# 70404  2015-09-30 23:59:53  10.1111/j.1365-2745.2008.01464.x  56ed2b96449d3
#
#       country      city                  coords
# 0      Canada  Montreal   45.5016889,-73.567256
# 1      Canada  Montreal   45.5016889,-73.567256
# 2      Canada  Montreal   45.5016889,-73.567256
# 3      Canada  Montreal   45.5016889,-73.567256
# 4      Canada  Montreal   45.5016889,-73.567256
# ...       ...       ...                     ...
# 70400  Canada  Edmonton  53.544389,-113.4909267
# 70401  Canada  Edmonton  53.544389,-113.4909267
# 70402  Canada  Edmonton  53.544389,-113.4909267
# 70403  Canada  Edmonton  53.544389,-113.4909267
# 70404  Canada  Edmonton  53.544389,-113.4909267
#
# [70405 rows x 6 columns]

# %%
#get rid of columns we don't need
sci_data.pop("coords")
sci_data.pop("country")
sci_data
# Out:
#                  timestamp                         doi_whole        user_id  \
# 0      2015-12-01 00:01:32           10.1109/PES.2007.385969  56ed2c29a40f2
# 1      2015-12-01 00:02:23          10.1109/PSC.2014.6808094  56ed2c29a40f2
# 2      2015-12-01 00:03:00          10.1109/PSC.2014.6808094  56ed2c29a40f2
# 3      2015-12-01 00:03:01      10.1007/978-3-642-30574-0_46  56ed2c29a40f2
# 4      2015-12-01 00:04:48           10.1109/PES.2007.385969  56ed2c29a40f2
# ...                    ...                               ...            ...
# 70400  2015-09-30 23:04:48              10.3732/ajb.94.5.887  56ed2b96449d3
# 70401  2015-09-30 23:15:36               10.1021/ja01145a045  56ed2b6a884ae
# 70402  2015-09-30 23:21:29               10.1021/ja02268a023  56ed2b6a884ae
# 70403  2015-09-30 23:58:20              10.5735/085.047.0605  56ed2b96449d3
# 70404  2015-09-30 23:59:53  10.1111/j.1365-2745.2008.01464.x  56ed2b96449d3
#
#            city
# 0      Montreal
# 1      Montreal
# 2      Montreal
# 3      Montreal
# 4      Montreal
# ...         ...
# 70400  Edmonton
# 70401  Edmonton
# 70402  Edmonton
# 70403  Edmonton
# 70404  Edmonton
#
# [70405 rows x 4 columns]

# %%
# split out DOI into all three pieces
sci_data["doi_prefix"] = sci_data.doi_whole.str.split('/',expand=True)[0]
sci_data["doi_suffix"] = sci_data.doi_whole.str.split('/',expand=True)[1]

# %%
#rearrange columns
sci_data = sci_data[["timestamp","user_id","city","doi_whole","doi_prefix","doi_suffix"]]
sci_data
# Out:
#                  timestamp        user_id      city  \
# 0      2015-12-01 00:01:32  56ed2c29a40f2  Montreal
# 1      2015-12-01 00:02:23  56ed2c29a40f2  Montreal
# 2      2015-12-01 00:03:00  56ed2c29a40f2  Montreal
# 3      2015-12-01 00:03:01  56ed2c29a40f2  Montreal
# 4      2015-12-01 00:04:48  56ed2c29a40f2  Montreal
# ...                    ...            ...       ...
# 70400  2015-09-30 23:04:48  56ed2b96449d3  Edmonton
# 70401  2015-09-30 23:15:36  56ed2b6a884ae  Edmonton
# 70402  2015-09-30 23:21:29  56ed2b6a884ae  Edmonton
# 70403  2015-09-30 23:58:20  56ed2b96449d3  Edmonton
# 70404  2015-09-30 23:59:53  56ed2b96449d3  Edmonton
#
#                               doi_whole doi_prefix                doi_suffix
# 0               10.1109/PES.2007.385969    10.1109           PES.2007.385969
# 1              10.1109/PSC.2014.6808094    10.1109          PSC.2014.6808094
# 2              10.1109/PSC.2014.6808094    10.1109          PSC.2014.6808094
# 3          10.1007/978-3-642-30574-0_46    10.1007      978-3-642-30574-0_46
# 4               10.1109/PES.2007.385969    10.1109           PES.2007.385969
# ...                                 ...        ...                       ...
# 70400              10.3732/ajb.94.5.887    10.3732              ajb.94.5.887
# 70401               10.1021/ja01145a045    10.1021               ja01145a045
# 70402               10.1021/ja02268a023    10.1021               ja02268a023
# 70403              10.5735/085.047.0605    10.5735              085.047.0605
# 70404  10.1111/j.1365-2745.2008.01464.x    10.1111  j.1365-2745.2008.01464.x
#
# [70405 rows x 6 columns]

# %%
#write this out as a proper CSV file
sci_data.to_csv('week_3_sci_hub_homework.csv',index=False)
