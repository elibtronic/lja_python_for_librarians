# %% [markdown]
# # San Francisco Library Usage Data prep

# %% [markdown]
# Downloaded from Kaggle
# Unzipped
# Put file `Library_Usage.csv` into same directory as notebook

# %%
import pandas as pd

dataframe = pd.read_csv("Library_Usage.csv")
dataframe.head(5)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 3                 SENIOR               28              13
# 1                 0                  ADULT               21              10
# 2                 0                  ADULT              275             559
# 3                 0                  ADULT               73              38
# 4                 0                  ADULT              182              90
#
#         Age Range Home Library Code Home Library Definition  \
# 0  65 to 74 years                 X            Main Library
# 1  55 to 59 years                 X            Main Library
# 2  60 to 64 years                 X            Main Library
# 3  45 to 54 years                M8             Mission Bay
# 4  45 to 54 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# 0                 November                    2012                      z
# 1                  October                    2015                      z
# 2                  January                    2015                      z
# 3                 February                    2016                      z
# 4                     July                    2016                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        email                    True
# 1                        email                    True
# 2                        email                    True
# 3                        email                    True
# 4                        email                    True
#
#    Year Patron Registered  Outside of County  Supervisor District
# 0                    2003               True                  NaN
# 1                    2003              False                  NaN
# 2                    2003               True                  NaN
# 3                    2003              False                  NaN
# 4                    2003              False                  NaN

# %%
#get rid of columns we don't need
dataframe.pop("Patron Type Code")
dataframe.pop("Age Range")
dataframe.pop("Supervisor District")
dataframe.pop("Outside of County")
dataframe.pop("Provided Email Address")
dataframe.pop("Notice Preference Code")
dataframe.pop("Notice Preference Definition")
dataframe.pop("Home Library Code")
# Out:
# 0          X
# 1          X
# 2          X
# 3         M8
# 4          X
#           ..
# 423443     X
# 423444     X
# 423445     X
# 423446    O7
# 423447    A5
# Name: Home Library Code, Length: 423448, dtype: object

# %%
dataframe.head(5)
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 SENIOR               28              13
# 1                  ADULT               21              10
# 2                  ADULT              275             559
# 3                  ADULT               73              38
# 4                  ADULT              182              90
#
#   Home Library Definition Circulation Active Month Circulation Active Year  \
# 0            Main Library                 November                    2012
# 1            Main Library                  October                    2015
# 2            Main Library                  January                    2015
# 3             Mission Bay                 February                    2016
# 4            Main Library                     July                    2016
#
#    Year Patron Registered
# 0                    2003
# 1                    2003
# 2                    2003
# 3                    2003
# 4                    2003

# %%
#make it a bit smaller

dataframe = dataframe.sample(n=10000,random_state=100)

# %%
dataframe.head()
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 366852            YOUNG ADULT                0               0
# 282253                  ADULT                3              12
# 396606               JUVENILE               11               0
# 311278               JUVENILE              171             111
# 361674            YOUNG ADULT               14               1
#
#             Home Library Definition Circulation Active Month  \
# 366852                       Marina                     None
# 282253                     Richmond                    April
# 396606  Bayview/Linda Brooks-Burton                     June
# 311278                       Merced                     July
# 361674                     Richmond                  October
#
#        Circulation Active Year  Year Patron Registered
# 366852                    None                    2015
# 282253                    2014                    2013
# 396606                    2014                    2010
# 311278                    2016                    2014
# 361674                    2013                    2011

# %%
dataframe.to_csv('week_2_san_francisco_worksheet.csv',index=False)
